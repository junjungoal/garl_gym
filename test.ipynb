# %%
import os
import numpy as np
from attrdict import AttrDict
from garl_gym.scenarios.simple_population_dynamics import SimplePopulationDynamics
import matplotlib.pyplot as plt

# %%
args = {'predator_num': 10, 'prey_num': 20, 'num_actions': 5, 'height': 30, 'damage_per_step': 0.01, 'img_length': 5, 'hunt_radius': np.sqrt(8),
        'width': 30, 'batch_size': 1, 'view_args': ['2500-5-5-0','2500-5-5-1','2500-5-5-2','2500-5-5-3']}
args = AttrDict(args)

# %%
env = SimplePopulationDynamics(args)

# %%
env.make_world(wall_prob=0.02)

# %%
len(env.agents)
# Out:
# 30

# %%
env.plot_map()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
env.plot_map()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for i in range(200):
    actions = np.random.randint(5, size=10)
    rewards = env.step(actions)
    print

# %%
env.plot_map()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
env.predators
env.preys
# Out:
# [<garl_gym.core.Agent at 0x118a26668>, <garl_gym.core.Agent at 0x118a268d0>]

# %%
env.agents

# %%
np.sqrt(8)
# Out:
# 2.8284271247461903

# %%
env.predators
